# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from pandas import DataFrame

# %%
csv = pd.read_csv("20220902_data1.csv")

# %%
csv
# Out:
#        X         -1/rA
# 0   0.00  8.804200e-07
# 1   0.02  9.022960e-07
# 2   0.04  9.251180e-07
# 3   0.06  9.489470e-07
# 4   0.08  9.738490e-07
# 5   0.10  9.998970e-07
# 6   0.12  1.027170e-06
# 7   0.14  1.055750e-06
# 8   0.16  1.085740e-06
# 9   0.18  1.117230e-06
# 10  0.20  1.150350e-06
# 11  0.22  1.185210e-06
# 12  0.24  1.221950e-06
# 13  0.26  1.260740e-06
# 14  0.28  1.301730e-06
# 15  0.30  1.345130e-06
# 16  0.32  1.391130e-06
# 17  0.34  1.439990e-06
# 18  0.36  1.491960e-06
# 19  0.38  1.547360e-06
# 20  0.40  1.606520e-06
# 21  0.42  1.669840e-06
# 22  0.44  1.737750e-06
# 23  0.46  1.810780e-06
# 24  0.48  1.889510e-06
# 25  0.50  1.974640e-06
# 26  0.52  2.066950e-06
# 27  0.54  2.167400e-06
# 28  0.56  2.277090e-06
# 29  0.58  2.397330e-06
# 30  0.60  2.529730e-06
# 31  0.62  2.676190e-06
# 32  0.64  2.839070e-06
# 33  0.66  3.021270e-06
# 34  0.68  3.226400e-06
# 35  0.70  3.459060e-06
# 36  0.72  3.725150e-06
# 37  0.74  4.032390e-06
# 38  0.76  4.391070e-06
# ...

# %%
plt.show()

# %%
csv[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/code/sci8/env/lib/python3.8/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/code/sci8/env/lib/python3.8/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/code/sci8/env/lib/python3.8/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
csv.iloc[0]
# Out:
# X        0.000000e+00
# -1/rA    8.804200e-07
# Name: 0, dtype: float64

# %%
csv.iloc[:, 0]
# Out:
# 0     0.00
# 1     0.02
# 2     0.04
# 3     0.06
# 4     0.08
# 5     0.10
# 6     0.12
# 7     0.14
# 8     0.16
# 9     0.18
# 10    0.20
# 11    0.22
# 12    0.24
# 13    0.26
# 14    0.28
# 15    0.30
# 16    0.32
# 17    0.34
# 18    0.36
# 19    0.38
# 20    0.40
# 21    0.42
# 22    0.44
# 23    0.46
# 24    0.48
# 25    0.50
# 26    0.52
# 27    0.54
# 28    0.56
# 29    0.58
# 30    0.60
# 31    0.62
# 32    0.64
# 33    0.66
# 34    0.68
# 35    0.70
# 36    0.72
# 37    0.74
# 38    0.76
# 39    0.78
# 40    0.80
# 41    0.82
# 42    0.84
# 43    0.86
# 44    0.88
# 45    0.90
# Name: X, dtype: float64

# %%
plt.plot(csv.iloc[:, 0], csv.iloc[:, 1])
plt.show()
